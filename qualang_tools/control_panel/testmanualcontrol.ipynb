# %%
from qm.qua import *
from qm import QuantumMachinesManager
from qm import SimulationConfig
from configuration_with_lf_fem_and_mw_fem import *
from manual_output_control import ManualOutputControl

# test for opx1000, load a config
moc_opx1k_cfg = config
moc_opx1k = ManualOutputControl(moc_opx1k_cfg, host=qop_ip, port=qop_port, cluster_name=cluster_name, close_previous=True)
ManualOutputControl.print_analog_status(moc_opx1k)
ManualOutputControl.print_digital_status(moc_opx1k)
# Out:
# 2025-11-24 20:32:29,396 - qm - INFO     - Performing health check
# 2025-11-24 20:32:29,892 - qm - INFO     - Cluster healthcheck completed successfully.
# 2025-11-24 20:32:31,268 - qm - WARNING  - No calibration_db set in octave config, skipping loading calibration data
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/program/_qua_config_schema.py:1880: DeprecationWarning:
#
# 'version' is deprecated since "1.2.2" and will be removed in "1.3.0". Please remove it from the Qua config.
# 2025-11-24 20:32:31,768 - qm - INFO     - Clearing queue
# 2025-11-24 20:32:32,727 - qm - INFO     - Adding program to queue.
# If an element is turned on without an explicit amplitude, the amplitude defaults to 0.5 V.
# testele - Amplitude: 0, Frequency: 100000000.0
# testele2 - Amplitude: 0, Frequency: 100000000.0
# trigger - Amplitude: 0, Frequency: 0.0

# %%
# load a config, but with a specified loaded element
moc_opx1k = ManualOutputControl(moc_opx1k_cfg, host=qop_ip, port=qop_port, cluster_name=cluster_name, elements_to_control=['testele'], close_previous=True)
ManualOutputControl.print_analog_status(moc_opx1k)
ManualOutputControl.print_digital_status(moc_opx1k)
# Out:
# 2025-11-24 20:32:35,612 - qm - INFO     - Performing health check
# 2025-11-24 20:32:36,069 - qm - INFO     - Cluster healthcheck completed successfully.
# 2025-11-24 20:32:37,192 - qm - WARNING  - No calibration_db set in octave config, skipping loading calibration data
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/program/_qua_config_schema.py:1880: DeprecationWarning:
#
# 'version' is deprecated since "1.2.2" and will be removed in "1.3.0". Please remove it from the Qua config.
# 2025-11-24 20:32:37,707 - qm - INFO     - Clearing queue
# 2025-11-24 20:32:38,683 - qm - INFO     - Adding program to queue.
# If an element is turned on without an explicit amplitude, the amplitude defaults to 0.5 V.
# testele - Amplitude: 0, Frequency: 100000000.0

# %%
lffem = 5
# specify ports to control
moc_opx1k_ports = ManualOutputControl.ports(
    isopx1k=True,
    analog_ports=[
        ("con1", lffem, 6),                     # LF single
        (("con1", lffem, 7),("con1", lffem, 8)),
    ],
    digital_ports=[
    ],
    fem_types={
        ("con1", lffem): "LF",
    },
    host=qop_ip,
    port=qop_port,
    cluster_name=cluster_name,
    close_previous=True,
)

print("isopx1k (ports OPX1000):", moc_opx1k_ports.isopx1k)
print("Analog elements:", moc_opx1k_ports.analog_elements)
print("Digital elements:", moc_opx1k_ports.digital_elements)

ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
# Out:
# 2025-11-24 20:32:41,433 - qm - INFO     - Performing health check
# 2025-11-24 20:32:41,887 - qm - INFO     - Cluster healthcheck completed successfully.
# 2025-11-24 20:32:43,054 - qm - WARNING  - No calibration_db set in octave config, skipping loading calibration data
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/program/_qua_config_schema.py:1880: DeprecationWarning:
#
# 'version' is deprecated since "1.2.2" and will be removed in "1.3.0". Please remove it from the Qua config.
# 2025-11-24 20:32:43,563 - qm - INFO     - Clearing queue
# 2025-11-24 20:32:44,531 - qm - INFO     - Adding program to queue.
# If an element is turned on without an explicit amplitude, the amplitude defaults to 0.5 V.
# isopx1k (ports OPX1000): True
# Analog elements: ["('con1', 5, 6)", "(('con1', 5, 7), ('con1', 5, 8))"]
# Digital elements: []
# ('con1', 5, 6) - Amplitude: 0, Frequency: 0.0
# (('con1', 5, 7), ('con1', 5, 8)) - Amplitude: 0, Frequency: 0.0

# %%
# test turn_on_element and turn_off_element
import time
lffemport = "('con1', " + str(lffem) + ", 6)"
moc_opx1k_ports.turn_on_element(lffemport, amplitude=0.5, frequency=300e6)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.turn_off_elements(lffemport)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
# Out:
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
#
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
# ('con1', 5, 6) - Amplitude: 0.4999847412109375, Frequency: 300000000.0
# (('con1', 5, 7), ('con1', 5, 8)) - Amplitude: 0, Frequency: 0.0
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
# ...

# %%
# test turn_on_element and turn_off_element
import time
lffemport = ('con1', lffem, 6)
moc_opx1k_ports.turn_on_element(lffemport, amplitude=0.5, frequency=300e6)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.turn_off_elements(lffemport)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)

# %%
# test turn_on_element without amplitude
moc_opx1k_ports.turn_on_element(lffemport, frequency=300e6)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.turn_off_elements(lffemport)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
# Out:
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
#
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
# ('con1', 5, 6) - Amplitude: 0.4999847412109375, Frequency: 300000000.0
# (('con1', 5, 7), ('con1', 5, 8)) - Amplitude: 0, Frequency: 0.0
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
# ...

# %%
# test turn_on_element without frequency
moc_opx1k_ports.turn_on_element(lffemport, amplitude=0.2)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.turn_off_elements(lffemport)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
# Out:
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
# ('con1', 5, 6) - Amplitude: 0.1999969482421875, Frequency: 300000000.0
# (('con1', 5, 7), ('con1', 5, 8)) - Amplitude: 0, Frequency: 0.0
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
# ('con1', 5, 6) - Amplitude: -1.52587890625e-05, Frequency: 300000000.0
# (('con1', 5, 7), ('con1', 5, 8)) - Amplitude: 0, Frequency: 0.0

# %%
# test turn_on_element without frequency and amplitude
moc_opx1k_ports.turn_on_element(lffemport)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.turn_off_elements(lffemport)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
# Out:
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
# ('con1', 5, 6) - Amplitude: 0.499969482421875, Frequency: 300000000.0
# (('con1', 5, 7), ('con1', 5, 8)) - Amplitude: 0, Frequency: 0.0
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
# ('con1', 5, 6) - Amplitude: -1.52587890625e-05, Frequency: 300000000.0
# (('con1', 5, 7), ('con1', 5, 8)) - Amplitude: 0, Frequency: 0.0

# %%
# test set amplitude
moc_opx1k_ports.set_amplitude(lffemport,0.3)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.set_amplitude(lffemport,0.2)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.set_amplitude(lffemport,0.1)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
moc_opx1k_ports.turn_off_elements(lffemport)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
# Out:
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
# ('con1', 5, 6) - Amplitude: 0.29998779296875, Frequency: 300000000.0
# (('con1', 5, 7), ('con1', 5, 8)) - Amplitude: 0, Frequency: 0.0
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
# ('con1', 5, 6) - Amplitude: 0.1999969482421875, Frequency: 300000000.0
# (('con1', 5, 7), ('con1', 5, 8)) - Amplitude: 0, Frequency: 0.0
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# ...

# %%
# test set frequency
moc_opx1k_ports.turn_on_element(lffemport)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
moc_opx1k_ports.set_frequency(lffemport,100e6)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.set_frequency(lffemport,200e6)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.set_frequency(lffemport,300e6)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.set_frequency(lffemport,400e6)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.turn_off_elements(lffemport)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
# Out:
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
# ('con1', 5, 6) - Amplitude: 0.4999847412109375, Frequency: 300000000.0
# (('con1', 5, 7), ('con1', 5, 8)) - Amplitude: 0, Frequency: 0.0
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
# ('con1', 5, 6) - Amplitude: 0.4999847412109375, Frequency: 100000000.0
# (('con1', 5, 7), ('con1', 5, 8)) - Amplitude: 0, Frequency: 0.0
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# ...

# %%
moc_opx1k_ports.analog_status()
# Out:
# {"('con1', 5, 6)": {'amplitude': 0.0, 'frequency': 400000000.0},
#  "(('con1', 5, 7), ('con1', 5, 8))": {'amplitude': 0, 'frequency': 0.0}}

# %%
# test lffem IQ
lffem = 5
# specify ports to control
moc_opx1k_ports = ManualOutputControl.ports(
    isopx1k=True,
    analog_ports=[
        (("con1", lffem, 5),("con1", lffem, 6)),
    ],
    digital_ports=[
    ],
    fem_types={
        ("con1", lffem): "LF",
    },
    host=qop_ip,
    port=qop_port,
    cluster_name=cluster_name,
    close_previous=True,
)

print("isopx1k (ports OPX1000):", moc_opx1k_ports.isopx1k)
print("Analog elements:", moc_opx1k_ports.analog_elements)
print("Digital elements:", moc_opx1k_ports.digital_elements)

ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)

lffemIQ = "(('con1', " +str(lffem) + ", 5), ('con1', " + str(lffem) + ", 6))"

moc_opx1k_ports.turn_on_element(lffemIQ, frequency=300e6)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.turn_off_elements(lffemIQ)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
# Out:
# 2025-11-24 20:33:56,406 - qm - INFO     - Performing health check
# 2025-11-24 20:33:56,823 - qm - INFO     - Cluster healthcheck completed successfully.
# 2025-11-24 20:33:57,982 - qm - WARNING  - No calibration_db set in octave config, skipping loading calibration data
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/program/_qua_config_schema.py:1880: DeprecationWarning:
#
# 'version' is deprecated since "1.2.2" and will be removed in "1.3.0". Please remove it from the Qua config.
# 2025-11-24 20:33:58,494 - qm - INFO     - Clearing queue
# 2025-11-24 20:33:59,468 - qm - INFO     - Adding program to queue.
# If an element is turned on without an explicit amplitude, the amplitude defaults to 0.5 V.
# isopx1k (ports OPX1000): True
# Analog elements: ["(('con1', 5, 5), ('con1', 5, 6))"]
# Digital elements: []
# (('con1', 5, 5), ('con1', 5, 6)) - Amplitude: 0, Frequency: 0.0
# ...

# %%
# test with mwfem
mwfem = 1
# specify ports to control
moc_opx1k_ports = ManualOutputControl.ports(
    isopx1k=True,
    analog_ports=[
        ("con1", mwfem, 2),     
        ("con1", mwfem, 3),
    ],
    digital_ports=[
        ("con1", mwfem, 7),                     # MW digital
        ("con1", mwfem, 8),                    
    ],
    fem_types={
        ("con1", mwfem): "MW",
    },
    mw_output_params={
        ("con1", mwfem, 2): {"band": 1, "full_scale_power_dbm": 10,  "upconverter_frequency": 2e9 },
        ("con1", mwfem, 3): {"band": 1, "full_scale_power_dbm": 10,  "upconverter_frequency": 2e9 },
    },
    host=qop_ip,
    port=qop_port,
    cluster_name=cluster_name,
    close_previous=True,
)

ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
# Out:
# 2025-11-24 20:34:11,126 - qm - INFO     - Performing health check
# 2025-11-24 20:34:11,570 - qm - INFO     - Cluster healthcheck completed successfully.
# 2025-11-24 20:34:12,940 - qm - WARNING  - No calibration_db set in octave config, skipping loading calibration data
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/program/_qua_config_schema.py:1880: DeprecationWarning:
#
# 'version' is deprecated since "1.2.2" and will be removed in "1.3.0". Please remove it from the Qua config.
# 2025-11-24 20:34:13,432 - qm - WARNING  - No calibration_db set in octave config, skipping loading calibration data
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/program/_qua_config_schema.py:1880: DeprecationWarning:
#
# 'version' is deprecated since "1.2.2" and will be removed in "1.3.0". Please remove it from the Qua config.
# 2025-11-24 20:34:13,932 - qm - WARNING  - No calibration_db set in octave config, skipping loading calibration data
# ...

# %%
# test turn_on_element and turn_off_element
import time
mwfemport = "('con1', " + str(mwfem) + ", 2)"
moc_opx1k_ports.turn_on_element(mwfemport, amplitude=0.5, frequency=300e6)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.turn_off_elements(mwfemport)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
# test turn_on_element without amplitude
moc_opx1k_ports.turn_on_element(mwfemport, frequency=300e6)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.turn_off_elements(mwfemport)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
# test turn_on_element without frequency
moc_opx1k_ports.turn_on_element(mwfemport, amplitude=0.2)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.turn_off_elements(mwfemport)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
# test turn_on_element without frequency and amplitude
moc_opx1k_ports.turn_on_element(mwfemport)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.turn_off_elements(mwfemport)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
# test set amplitude
moc_opx1k_ports.set_amplitude(mwfemport,0.3)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.set_amplitude(mwfemport,0.2)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.set_amplitude(mwfemport,0.1)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
moc_opx1k_ports.turn_off_elements(mwfemport)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
# test set frequency
moc_opx1k_ports.turn_on_element(mwfemport)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
moc_opx1k_ports.set_frequency(mwfemport,100e6)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.set_frequency(mwfemport,200e6)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.set_frequency(mwfemport,300e6)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.set_frequency(mwfemport,400e6)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.turn_off_elements(mwfemport)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
# Out:
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
#
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
# ('con1', 1, 2) - Amplitude: 0.4999847412109375, Frequency: 300000000.0
# ('con1', 1, 3) - Amplitude: 0, Frequency: 0.0
# ('con1', 1, 7) - False
# ('con1', 1, 8) - False
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# ...

# %%
# test the digital channels on and off
moc_opx1k_ports.digital_on()
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.digital_off()
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
# Out:
# 2025-11-24 20:35:26,331 - qm - INFO     - Clearing queue
# 2025-11-24 20:35:27,269 - qm - INFO     - Adding program to queue.
# 2025-11-24 20:35:28,018 - qm - INFO     - Clearing queue
# 2025-11-24 20:35:28,987 - qm - INFO     - Adding program to queue.
# ('con1', 1, 2) - Amplitude: 0.0, Frequency: 400000000.0
# ('con1', 1, 3) - Amplitude: 0, Frequency: 0.0
# ('con1', 1, 7) - True
# ('con1', 1, 8) - True
# ('con1', 1, 2) - Amplitude: 0.0, Frequency: 400000000.0
# ('con1', 1, 3) - Amplitude: 0, Frequency: 0.0
# ('con1', 1, 7) - False
# ('con1', 1, 8) - False

# %%
# test specific digital channel on and off
digichan = "('con1', " + str(mwfem) + ", 7)"
moc_opx1k_ports.digital_on(digichan)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.digital_off(digichan)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
# Out:
# 2025-11-24 20:35:35,206 - qm - INFO     - Clearing queue
# 2025-11-24 20:35:36,179 - qm - INFO     - Adding program to queue.
# ('con1', 1, 2) - Amplitude: 0.0, Frequency: 400000000.0
# ('con1', 1, 3) - Amplitude: 0, Frequency: 0.0
# ('con1', 1, 7) - True
# ('con1', 1, 8) - False
# ('con1', 1, 2) - Amplitude: 0.0, Frequency: 400000000.0
# ('con1', 1, 3) - Amplitude: 0, Frequency: 0.0
# ('con1', 1, 7) - False
# ('con1', 1, 8) - False

# %%
# test digital switch
moc_opx1k_ports.digital_switch(digichan)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
time.sleep(3)
moc_opx1k_ports.digital_switch(digichan)
ManualOutputControl.print_analog_status(moc_opx1k_ports)
ManualOutputControl.print_digital_status(moc_opx1k_ports)
# Out:
# 2025-11-24 20:35:42,864 - qm - INFO     - Clearing queue
# 2025-11-24 20:35:43,842 - qm - INFO     - Adding program to queue.
# ('con1', 1, 2) - Amplitude: 0.0, Frequency: 400000000.0
# ('con1', 1, 3) - Amplitude: 0, Frequency: 0.0
# ('con1', 1, 7) - True
# ('con1', 1, 8) - False
# ('con1', 1, 2) - Amplitude: 0.0, Frequency: 400000000.0
# ('con1', 1, 3) - Amplitude: 0, Frequency: 0.0
# ('con1', 1, 7) - False
# ('con1', 1, 8) - False

# %%
moc_opx1k_ports.close()

# %%
# test running two parallel process with same LFFEM
lffem = 5
# specify ports to control
moc_opx1k_ports_1 = ManualOutputControl.ports(
    isopx1k=True,
    analog_ports=[
        ("con1", lffem, 7),
    ],
    digital_ports=[
    ],
    fem_types={
        ("con1", lffem): "LF",
    },
    host=qop_ip,
    port=qop_port,
    cluster_name=cluster_name,
    close_previous=True,
)

moc_opx1k_ports_2 = ManualOutputControl.ports(
    isopx1k=True,
    analog_ports=[
        ("con1", lffem, 6),                     # LF single
    ],
    digital_ports=[
    ],
    fem_types={
        ("con1", lffem): "LF",
    },
    host=qop_ip,
    port=qop_port,
    cluster_name=cluster_name,
    close_previous=False,
)

ManualOutputControl.print_analog_status(moc_opx1k_ports_1)
ManualOutputControl.print_digital_status(moc_opx1k_ports_1)
ManualOutputControl.print_analog_status(moc_opx1k_ports_2)
ManualOutputControl.print_digital_status(moc_opx1k_ports_2)
# Out:
# 2025-11-24 20:35:54,175 - qm - INFO     - Performing health check
# 2025-11-24 20:35:54,630 - qm - INFO     - Cluster healthcheck completed successfully.
# 2025-11-24 20:35:55,126 - qm - WARNING  - No calibration_db set in octave config, skipping loading calibration data
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/program/_qua_config_schema.py:1880: DeprecationWarning:
#
# 'version' is deprecated since "1.2.2" and will be removed in "1.3.0". Please remove it from the Qua config.
# 2025-11-24 20:35:55,641 - qm - INFO     - Clearing queue
# 2025-11-24 20:35:56,623 - qm - INFO     - Adding program to queue.
# If an element is turned on without an explicit amplitude, the amplitude defaults to 0.5 V.
# 2025-11-24 20:35:59,247 - qm - INFO     - Performing health check
# 2025-11-24 20:35:59,702 - qm - INFO     - Cluster healthcheck completed successfully.
# ...

# %%
lffemport1 = "('con1', " + str(lffem) + ", 7)"
lffemport2 = "('con1', " + str(lffem) + ", 6)"

moc_opx1k_ports_2.turn_on_element(lffemport2, amplitude=0.2, frequency = 100e6)
ManualOutputControl.print_analog_status(moc_opx1k_ports_2)
ManualOutputControl.print_digital_status(moc_opx1k_ports_2)
time.sleep(3)
moc_opx1k_ports_1.turn_on_element(lffemport1, amplitude=0.2, frequency = 200e6)
ManualOutputControl.print_analog_status(moc_opx1k_ports_1)
ManualOutputControl.print_digital_status(moc_opx1k_ports_1)
moc_opx1k_ports_2.turn_off_elements(lffemport2)
ManualOutputControl.print_analog_status(moc_opx1k_ports_2)
ManualOutputControl.print_digital_status(moc_opx1k_ports_2)
time.sleep(3)
moc_opx1k_ports_1.turn_off_elements(lffemport1)
ManualOutputControl.print_analog_status(moc_opx1k_ports_2)
ManualOutputControl.print_digital_status(moc_opx1k_ports_2)
# Out:
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
#
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
# ('con1', 5, 6) - Amplitude: 0.1999969482421875, Frequency: 100000000.0
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/api/v2/qm_api_old.py:850: DeprecationWarning:
#
# qm.set_io_values is deprecated since "1.2.0" and will be removed in "1.4.0". This method is going to be moved to the job API, please use `job.set_io_values()`
#
# ...

# %%
moc_opx1k_ports_1.close()
moc_opx1k_ports_2.close()

# %%
from configuration import *
from qm.qua import *
from qm import QuantumMachinesManager
from qm import SimulationConfig
from manual_output_control import ManualOutputControl

# test with OPX+ 
opx_plus_config = config
moc_opx = ManualOutputControl(
    opx_plus_config,
    host=qop_ip,
    port=qop_port,
    cluster_name=cluster_name,
    close_previous=True,
)

print("isopx1k:", moc_opx.isopx1k)
print("Analog elements:", moc_opx.analog_elements)
print("Digital elements:", moc_opx.digital_elements)

ManualOutputControl.print_analog_status(moc_opx)
ManualOutputControl.print_digital_status(moc_opx)

ManualOutputControl.print_analog_status(moc_opx)
ManualOutputControl.print_digital_status(moc_opx)

# Try turning things on
for el in moc_opx.analog_elements:
    print(el)
    moc_opx.turn_on_element(el, amplitude=0.5, frequency=10e6)

moc_opx.digital_on()  # all digital elements
ManualOutputControl.print_analog_status(moc_opx)
ManualOutputControl.print_digital_status(moc_opx)
# Out:
# 2025-11-24 20:36:24,562 - qm - INFO     - Performing health check
# 2025-11-24 20:36:25,019 - qm - INFO     - Health check passed
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/program/_qua_config_schema.py:1880: DeprecationWarning:
#
# 'version' is deprecated since "1.2.2" and will be removed in "1.3.0". Please remove it from the Qua config.
# 2025-11-24 20:36:26,949 - qm - INFO     - Sending program to QOP for compilation
# 2025-11-24 20:36:27,662 - qm - INFO     - Executing program
# If an element is turned on without an explicit amplitude, the amplitude defaults to 0.5 V.
# isopx1k: False
# Analog elements: ['testele', 'testele2']
# Digital elements: []
# testele - Amplitude: 0, Frequency: 100000000.0
# testele2 - Amplitude: 0, Frequency: 200000000.0
# testele - Amplitude: 0, Frequency: 100000000.0
# testele2 - Amplitude: 0, Frequency: 200000000.0
# testele
# testele2
# testele - Amplitude: 0.4999847412109375, Frequency: 10000000.0
# ...

# %%
# from configuration import *
# from qm.qua import *
# from qm import QuantumMachinesManager
# from qm import SimulationConfig
# #from manual_output_control import ManualOutputControl
# from manual_output_control_original import ManualOutputControl

# test with OPX+ 
moc_opx_ports = ManualOutputControl.ports(
    #isopx1k=False,
    analog_ports= [1, (2, 3)],   # con1 port1 single, con1 ports 2&3 IQ
    digital_ports=[10],          # con1 port4 digital
    host=qop_ip,
    port=qop_port,
    cluster_name=cluster_name,
    close_previous=True,
)


ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)

# Try turning things on
for el in moc_opx_ports.analog_elements:
    print(el)
    moc_opx_ports.turn_on_element(el, amplitude=0.5, frequency=10e6)

moc_opx_ports.digital_on()  # all digital elements
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
moc_opx_ports.analog_config
# Out:
# 2025-11-24 20:36:36,175 - qm - INFO     - Performing health check
# 2025-11-24 20:36:36,632 - qm - INFO     - Health check passed
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/program/_qua_config_schema.py:1880: DeprecationWarning:
#
# 'version' is deprecated since "1.2.2" and will be removed in "1.3.0". Please remove it from the Qua config.
#
# /Users/chun-juwu/miniforge3/envs/qmenv/lib/python3.9/site-packages/qm/program/_qua_config_schema.py:1880: DeprecationWarning:
#
# 'version' is deprecated since "1.2.2" and will be removed in "1.3.0". Please remove it from the Qua config.
# 2025-11-24 20:36:38,997 - qm - INFO     - Sending program to QOP for compilation
# 2025-11-24 20:36:39,930 - qm - INFO     - Executing program
# If an element is turned on without an explicit amplitude, the amplitude defaults to 0.5 V.
# 1 - Amplitude: 0, Frequency: 0.0
# (2, 3) - Amplitude: 0, Frequency: 0.0
# 10 - False
# 1
# (2, 3)
# ...

# %%
# test turn_on_element and turn_off_element
import time
opxport = '1'
moc_opx_ports.turn_on_element(opxport, amplitude=0.5, frequency=300e6)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
time.sleep(3)
moc_opx_ports.turn_off_elements(opxport)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
# test turn_on_element without amplitude
moc_opx_ports.turn_on_element(opxport, frequency=300e6)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
time.sleep(3)
moc_opx_ports.turn_off_elements(opxport)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
# test turn_on_element without frequency
moc_opx_ports.turn_on_element(opxport, amplitude=0.2)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
time.sleep(3)
moc_opx_ports.turn_off_elements(opxport)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
# test turn_on_element without frequency and amplitude
moc_opx_ports.turn_on_element(opxport)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
time.sleep(3)
moc_opx_ports.turn_off_elements(opxport)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
# test set amplitude
moc_opx_ports.set_amplitude(opxport,0.3)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
time.sleep(3)
moc_opx_ports.set_amplitude(opxport,0.2)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
time.sleep(3)
moc_opx_ports.set_amplitude(opxport,0.1)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
moc_opx_ports.turn_off_elements(opxport)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
# test set frequency
moc_opx_ports.turn_on_element(opxport)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
moc_opx_ports.set_frequency(opxport,100e6)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
time.sleep(3)
moc_opx_ports.set_frequency(opxport,200e6)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
time.sleep(3)
moc_opx_ports.set_frequency(opxport,300e6)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
time.sleep(3)
moc_opx_ports.set_frequency(opxport,400e6)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
time.sleep(3)
moc_opx_ports.turn_off_elements(opxport)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
# Out:
# 1 - Amplitude: 0.4999847412109375, Frequency: 300000000.0
# (2, 3) - Amplitude: 0.4999847412109375, Frequency: 10000000.0
# 10 - True
# 1 - Amplitude: 0.0, Frequency: 300000000.0
# (2, 3) - Amplitude: 0.4999847412109375, Frequency: 10000000.0
# 10 - True
# 1 - Amplitude: 0.4999847412109375, Frequency: 300000000.0
# (2, 3) - Amplitude: 0.4999847412109375, Frequency: 10000000.0
# 10 - True
# 1 - Amplitude: 0.0, Frequency: 300000000.0
# (2, 3) - Amplitude: 0.4999847412109375, Frequency: 10000000.0
# 10 - True
# 1 - Amplitude: 0.1999969482421875, Frequency: 300000000.0
# (2, 3) - Amplitude: 0.4999847412109375, Frequency: 10000000.0
# 10 - True
# 1 - Amplitude: -1.52587890625e-05, Frequency: 300000000.0
# (2, 3) - Amplitude: 0.4999847412109375, Frequency: 10000000.0
# 10 - True
# 1 - Amplitude: 0.499969482421875, Frequency: 300000000.0
# (2, 3) - Amplitude: 0.4999847412109375, Frequency: 10000000.0
# 10 - True
# 1 - Amplitude: -1.52587890625e-05, Frequency: 300000000.0
# ...

# %%
# test the digital channels on and off
moc_opx_ports.digital_on()
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
time.sleep(3)
moc_opx_ports.digital_off()
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
# test specific digital channel on and off
digichan = 10
moc_opx_ports.digital_on(digichan)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
time.sleep(3)
moc_opx_ports.digital_off(digichan)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
# test digital switch
moc_opx_ports.digital_switch(digichan)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
time.sleep(3)
moc_opx_ports.digital_switch(digichan)
ManualOutputControl.print_analog_status(moc_opx_ports)
ManualOutputControl.print_digital_status(moc_opx_ports)
# Out:
# 1 - Amplitude: 0.0, Frequency: 400000000.0
# (2, 3) - Amplitude: 0.4999847412109375, Frequency: 10000000.0
# 10 - True
# 1 - Amplitude: 0.0, Frequency: 400000000.0
# (2, 3) - Amplitude: 0.4999847412109375, Frequency: 10000000.0
# 10 - False
# 2025-11-24 20:37:53,098 - qm - INFO     - Sending program to QOP for compilation
# 2025-11-24 20:37:53,807 - qm - INFO     - Executing program
# 1 - Amplitude: 0.0, Frequency: 400000000.0
# (2, 3) - Amplitude: 0.4999847412109375, Frequency: 10000000.0
# 10 - True
# 1 - Amplitude: 0.0, Frequency: 400000000.0
# (2, 3) - Amplitude: 0.4999847412109375, Frequency: 10000000.0
# 10 - False
# 2025-11-24 20:38:00,549 - qm - INFO     - Sending program to QOP for compilation
# 2025-11-24 20:38:01,266 - qm - INFO     - Executing program
# 1 - Amplitude: 0.0, Frequency: 400000000.0
# (2, 3) - Amplitude: 0.4999847412109375, Frequency: 10000000.0
# 10 - True
# 1 - Amplitude: 0.0, Frequency: 400000000.0
# ...

# %%
moc_opx_ports.analog_status()
# Out:
# {'1': {'amplitude': 0.0, 'frequency': 400000000.0},
#  '(2, 3)': {'amplitude': 0.4999847412109375, 'frequency': 10000000.0}}

# %%
moc_opx_ports.digital_status()
# Out:
# {'10': False}

# %%
moc_opx_ports.analog_config
# Out:
# {'version': 1,
#  'controllers': {'con1': {'type': 'opx1',
#    'analog_outputs': {1: {'offset': 0.0},
#     2: {'offset': 0.0},
#     3: {'offset': 0.0}}}},
#  'elements': {'1': {'singleInput': {'port': ('con1', 1)},
#    'intermediate_frequency': 0.0,
#    'operations': {'play': 'single_on'},
#    'hold_offset': {'duration': 16}},
#   '(2, 3)': {'mixInputs': {'I': ('con1', 2), 'Q': ('con1', 3)},
#    'intermediate_frequency': 0.0,
#    'operations': {'play': 'IQ_Ion'},
#    'hold_offset': {'duration': 16}}},
#  'waveforms': {'zero_wf': {'type': 'constant', 'sample': 0.0},
#   'const_wf': {'type': 'constant', 'sample': 0.4999847412109375}},
#  'pulses': {'single_on': {'operation': 'control',
#    'length': 16,
#    'waveforms': {'single': 'const_wf'}},
#   'IQ_Ion': {'operation': 'control',
#    'length': 16,
#    'waveforms': {'I': 'const_wf', 'Q': 'zero_wf'}}}}

# %%
moc_opx_ports.close()
